# %%
class Animal:
    def make_sound(self):
        print("Animals makes sounds")
class Dog(Animal):
    def make_sound(self):
        print("Dog sounds bark bark")
class Cat(Animal):
    def make_sound(self):
        print("Cat sounds meow meow")
class Cow:
    def make_sound(self):
        print("Cow sounds moos moos")
animals=[Dog(), Cat(), Cow()]
for animal in animals:
    animal.make_sound()
# Out:
# Dog sounds bark bark
# Cat sounds meow meow
# Cow sounds moos moos

# %%
class car:
    def start(self):
        print("car starts")
class Computer:
    def start(self):
        print("Computer boots")
class Washing_machine:
    def start(self):
        print("Washing machine starts")
def operate(device):
    device.start()
operate(car())
operate(Computer())
operate(Washing_machine())
# Out:
# car starts
# Computer boots
# Washing machine starts

# %%
class vector:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __add__(self,other):
        return vector(self.x + other.x, self.y + other.y)
    def __eq__(self,other):
        return self.x == other.x and self.y == other.y
    def __str__(self):
        return f"({self.x}, {self.y})"
v1=vector(2,3)
v2=vector(4,5)
print(v1 + v2)
print(v1 == v2)
# Out:
# (6, 8)
# False

# %%
class Transport:
    def move(self):
        print("Transport is moving")
class Bus(Transport):
    def move(self):
        super().move()
        print("Bus moving on road")
class Bike(Transport):
    def move(self):
        super().move()
        print("Bike moves fast")
b=Bus()
bk=Bike()
b.move()
bk.move()
# Out:
# Transport is moving
# Bus moving on road
# Transport is moving
# Bike moves fast

# %%
from abc import ABC,abstractmethod
class Notification(ABC):
    @abstractmethod
    def send(self):
        pass
class Emailnotification(Notification):
    def send(self):
        print("Email sent")
class SMSnotification(Notification):
    def send(self):
        print("SMS sent")
class Pushnotification(Notification):
    def send(self):
        print("Push notification sent")
notifications=[Emailnotification(), SMSnotification(), Pushnotification()]
for n in notifications:
    n.send()
# Out:
# Email sent
# SMS sent
# Push notification sent

# %%
class Payment:
    def process(self,amount):
        print("Amount:",amount)
class Creditcardpayment(Payment):
    def process(self,amount,card_type):
        print(f"Amount:{amount}")
        print(f"card Type:{card_type}")
p=Payment()
p.process(1000)
c=Creditcardpayment()
c.process(2000,"Visa")
# Out:
# Amount: 1000
# Amount:2000
# card Type:Visa

# %%
class BS:
    def logic(self):
        print("Bubble sort")
class MS:
    def logic(self):
        print("Merge sort")
class QS:
    def logic(self):
        print("Quick sort")
class Sorter:
    def change(self,strategy):
        self.strategy=strategy
    def sort(self):
        self.strategy.logic()
s=Sorter()

s.change(BS())
s.sort()

s.change(MS())
s.sort()

s.change(QS())
s.sort()
# Out:
# Bubble sort
# Merge sort
# Quick sort

# %%
class Account:
    def withdraw(self):
        print("Withdraw from Account")
class Savingsaccount(Account):
    def withdraw(self):
        print("savings account withdrawl")
class Premiumsavingsaccount(Savingsaccount):
    def withdraw(self):
        super().withdraw()
        print("Premium savings extra benefits")
a=Account()
s=Savingsaccount()
p=Premiumsavingsaccount()

a.withdraw()
s.withdraw()
p.withdraw()
# Out:
# Withdraw from Account
# savings account withdrawl
# savings account withdrawl
# Premium savings extra benefits

# %%
class Circle:
    def draw(self):
        print("Drawing circle")
class Square:
    def draw(self):
        print("Drawing Square")
class Rectangle:
    def draw(self):
        print("Drawing Rectangle")
class Car:
    def draw(Self):
        print("Drawing Car")
def draw(shape):
    shape.draw()
draw(Circle())
draw(Square())
draw(Rectangle())
draw(Car())
# Out:
# Drawing circle
# Drawing Square
# Drawing Rectangle
# Drawing Car

# %%
class UPI:
    def pay(self):
        print("paid using UPI")
class Card:
    def pay(self):
        print("paid using Card")
class Cash:
    def pay(self):
        print("paid using Cash")
payments=[UPI(), Card(), Cash()]
for p in payments:
    p.pay()
# Out:
# paid using UPI
# paid using Card
# paid using Cash

# %%
class UPI:
    def pay(self):
        print("paid using UPI")
class Card:
    def pay(self):
        print("paid using Card")
class Cash:
    def pay(self):
        print("paid using Cash")
def make_payment(obj):
    if isinstance(obj, UPI):
        obj.pay()
    elif isinstance(obj, Card):
        obj.pay()
    elif isinstance(obj, Cash):
        obj.pay()
    else:
        print("Invalid Payment")
make_payment(UPI())
make_payment(Card())
make_payment(Cash())
# Out:
# paid using UPI
# paid using Card
# paid using Cash
